# %%
from quantumnet.components import Network, Host
from quantumnet.objects import Qubit, Logger
Logger.activate(Logger)

# %%
rede = Network()
rede.set_ready_topology("Grade",3,3)
rede.draw()

# %%
alice = rede.get_host(1)
bob = rede.get_host(2)
qubit1 = Qubit(1)
qubit2 = Qubit(2)
alice.add_qubit(qubit1)
bob.add_qubit(qubit2)
# Out:
# 2024-06-02 23:27:40,916: Qubit 1 adicionado à memória do Host 1.
# 2024-06-02 23:27:40,917: Qubit 2 adicionado à memória do Host 2.

# %%
rede.link.request(1, 2)
# Out:
# 2024-06-02 23:27:40,923: A fidelidade do qubit Qubit 1 with state None é 1.0
# 2024-06-02 23:27:40,924: A fidelidade do qubit Qubit 2 with state None é 1.0
# 2024-06-02 23:27:40,924: A fidelidade entre o qubit Qubit 1 with state None e o qubit Qubit 2 with state None é 1.0
# 2024-06-02 23:27:40,924: O protocolo de criação de emaranhamento foi bem sucedido.
# 2024-06-02 23:27:40,925: Entrelaçamento criado com sucesso entre Host 1 e Host 2.

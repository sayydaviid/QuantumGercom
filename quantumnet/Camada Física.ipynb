# %%
from quantumnet.components import Network, Host
from quantumnet.objects import Qubit, Logger

# %%
rede = Network()
rede.set_ready_topology("Grade", 2, 3)
rede.draw()
# Out:
# Canais inicializados
# Hosts inicializados

# %%
# Criação de pares EPR
alice = rede.get_host(0)
bob = rede.get_host(1)
# Adicionando qubits aos hosts
alice.add_qubit(Qubit(0, 1))
bob.add_qubit(Qubit(1, 1))
# Acessando a memória dos hosts
print(alice.memory)
print(bob.memory)
print("Canais: ", rede.edges)
# Out:
# [<quantumnet.objects.qubit.Qubit object at 0x000001BE4E650950>]
# [<quantumnet.objects.qubit.Qubit object at 0x000001BE4E650F50>]
# Canais:  [(0, 3), (0, 1), (1, 4), (1, 2), (2, 5), (3, 4), (4, 5)]

# %%
# Usando as funções da camada física
# rede.start_hosts_and_channels()
rede.start_channels()
rede.start_hosts()
rede.physical.echp_on_replay(0, 1)
# Out:
# Canais inicializados
# Hosts inicializados
# True

# %%
rede.edges[0, 1]
# Out:
# {'prob_on_demand_epr_create': 0.8311679816029374,
#  'prob_replay_epr_create': 0.7916824816690564,
#  'eprs': [<quantumnet.objects.epr.Epr at 0x1be4e6a20c0>]}
